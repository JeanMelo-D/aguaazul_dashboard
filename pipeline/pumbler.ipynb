# %%
from azure_financial import azul_doc_partner
import polars as pl

def azul_fornecedores_lazy() -> pl.LazyFrame:
    azul_df_partner =azul_doc_partner().lazy()
    
    return azul_df_partner



xx = azul_fornecedores_lazy()


print(xx.collect().collect_schema())
# Out:
# Schema([('CardCode', String), ('Razao_Social', String), ('TIPO', String), ('CardType', String), ('GroupCode', Int32), ('GroupName', String), ('CmpPrivate', String), ('Address', String), ('ZipCode', String), ('MailAddres', String), ('MailZipCod', String), ('Balance', Decimal(precision=38, scale=18)), ('City', String), ('County', String), ('Country', String)])
