# %%
import polars as pl
from login import azul_contas_bancarias, azul_doc_a_pagar, azul_doc_pagos
import xlsxwriter 

contas = azul_contas_bancarias()
abertos = azul_doc_a_pagar()
pagos = azul_doc_pagos()



print (contas)
# Out:
# shape: (16_366, 18)
# ┌────────┬──────────────┬──────────────┬──────────┬───┬─────────┬─────────┬──────────────┬─────────┐
# │ DocNum ┆ DataPagament ┆ Pagamento_Do ┆ CashAcct ┆ … ┆ Finanse ┆ Details ┆ U_IB_ItemFlu ┆ CashBox │
# │ ---    ┆ o            ┆ cEntry       ┆ ---      ┆   ┆ ---     ┆ ---     ┆ xo           ┆ ---     │
# │ i32    ┆ ---          ┆ ---          ┆ str      ┆   ┆ str     ┆ str     ┆ ---          ┆ str     │
# │        ┆ datetime[ns] ┆ i32          ┆          ┆   ┆         ┆         ┆ i32          ┆         │
# ╞════════╪══════════════╪══════════════╪══════════╪═══╪═════════╪═════════╪══════════════╪═════════╡
# │ 12976  ┆ 2025-06-30   ┆ 14488        ┆ null     ┆ … ┆ N       ┆ null    ┆ null         ┆ N       │
# │        ┆ 00:00:00     ┆              ┆          ┆   ┆         ┆         ┆              ┆         │
# │ 12977  ┆ 2025-06-30   ┆ 14489        ┆ null     ┆ … ┆ N       ┆ null    ┆ null         ┆ N       │
# ...
